# %% [markdown]
# ## 0 - Setup

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## 1 - Importing Data

# %%
mens_df = pd.read_csv('../data/mens.csv',header=0,parse_dates=["Date"])
womens_df = pd.read_csv('../data/womens.csv',header=0,parse_dates=["Date"])

# %%
mens_df.head()
# Out:
#    ATP  Location                          Tournament       Date  \
# 0    1  Adelaide  Australian Hardcourt Championships 2000-01-03
# 1    1  Adelaide  Australian Hardcourt Championships 2000-01-03
# 2    1  Adelaide  Australian Hardcourt Championships 2000-01-03
# 3    1  Adelaide  Australian Hardcourt Championships 2000-01-03
# 4    1  Adelaide  Australian Hardcourt Championships 2000-01-03
#
#           Series    Court Surface      Round  Best of       Winner  ... UBW  \
# 0  International  Outdoor    Hard  1st Round        3   Dosedel S.  ... NaN
# 1  International  Outdoor    Hard  1st Round        3   Enqvist T.  ... NaN
# 2  International  Outdoor    Hard  1st Round        3    Escude N.  ... NaN
# 3  International  Outdoor    Hard  1st Round        3   Federer R.  ... NaN
# 4  International  Outdoor    Hard  1st Round        3  Fromberg R.  ... NaN
#
#   UBL LBW  LBL  SJW SJL MaxW MaxL AvgW  AvgL
# 0 NaN NaN  NaN  NaN NaN  NaN  NaN  NaN   NaN
# 1 NaN NaN  NaN  NaN NaN  NaN  NaN  NaN   NaN
# 2 NaN NaN  NaN  NaN NaN  NaN  NaN  NaN   NaN
# 3 NaN NaN  NaN  NaN NaN  NaN  NaN  NaN   NaN
# 4 NaN NaN  NaN  NaN NaN  NaN  NaN  NaN   NaN
#
# [5 rows x 54 columns]

# %%
womens_df.head()
# Out:
#    WTA  Location   Tournament       Date    Tier    Court Surface      Round  \
# 0    1  Auckland  ASB Classic 2007-01-01  Tier 4  Outdoor    Hard  1st Round
# 1    1  Auckland  ASB Classic 2007-01-01  Tier 4  Outdoor    Hard  1st Round
# 2    1  Auckland  ASB Classic 2007-01-01  Tier 4  Outdoor    Hard  1st Round
# 3    1  Auckland  ASB Classic 2007-01-01  Tier 4  Outdoor    Hard  1st Round
# 4    1  Auckland  ASB Classic 2007-01-01  Tier 4  Outdoor    Hard  1st Round
#
#    Best of      Winner  ...   UBW   UBL  LBW  LBL  SJW  SJL  MaxW  MaxL  AvgW  \
# 0        3    Sun T.T.  ...  1.35  3.05  NaN  NaN  NaN  NaN   NaN   NaN   NaN
# 1        3    Dulko G.  ...  3.75  1.25  NaN  NaN  NaN  NaN   NaN   NaN   NaN
# 2        3     Loit E.  ...   NaN   NaN  NaN  NaN  NaN  NaN   NaN   NaN   NaN
# 3        3  Craybas J.  ...   NaN   NaN  NaN  NaN  NaN  NaN   NaN   NaN   NaN
# 4        3  Bartoli M.  ...  1.20  4.30  NaN  NaN  NaN  NaN   NaN   NaN   NaN
#
#    AvgL
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
#
# [5 rows x 42 columns]

# %% [markdown]
# ## 2 - EDA
